# %% [markdown]
# # 计算机视觉
# 什么是计算机视觉（Computer Vision）？\
# 计算机视觉是人工智能 (AI) 的一个领域，是指让计算机和系统能够从图像、视频和其他视觉输入中获取有意义的信息，并根据该信息采取行动或提供建议。
#
# 工作原理\
# 计算机视觉需要大量数据。它一遍又一遍地运行数据分析，直到能够辨别差异并最终识别图像为止。\
# 这个过程会用到两种关键技术：一种是机器学习，叫做 深度学习，另一种是卷积神经网络 (CNN)。
#
# - 机器学习使用算法模型，让计算机能够自行学习视觉数据的上下文。
# - CNN 将图像分解为像素，并为像素指定标记或标签，从而使机器学习或深度学习模型能够"看"到物体。 它使用标签来执行卷积运算（用两个函数产生第三个函数的数学运算）并预测它"看到"的东西。 该神经网络运行卷积运算，并通过一系列迭代检验预测准确度，直到预测开始接近事实。

# %% [markdown]
# ### Transfer Learning
# Transfer Learning[1]: a common and effective strategy to train a network on a small dataset, where a network is pretrained on an extremely large dataset, such as ImageNet, then reused and applied to the given task of interest (such as classification of features). Two types of transfer learning methods: Fixed Feature Extraction, and Fine-tuning.
#
# ### Identity mapping
# https://medium.com/deepreview/review-of-identity-mappings-in-deep-residual-networks-ad6533452f33
#
# ### Max pooling
# https://www.geeksforgeeks.org/cnn-introduction-to-pooling-layer/

# %% [markdown]
# ### Networks I learned/learning
# With the purpose of identifying deep learning research on medical images:
# - UNet: used for image segmentation purposes (images, and their masks)
# - ResNet: used for ImageNet challenge datasets for classification of features/objects etc. Utilizes the strategy called “Transfer Learning” that uses a pretrained deep learning network (such as ResNet) to achieve its goal. ResNet helps to solve the problem with deep learning – the Vanishing/Exploding gradient problem, by allowing skip connections feature between Residual Blocks.
# - VGG: similar to ResNet, also used for ImageNet challenge datasets

# %% [markdown]
# ### My own resnet/vgg implementation
# Accuracy problem: after running over 50 epochs the best accuracy is still subpar around 70% accurate… Perhaps due to the fact that unlike a pretrained network with thousands of images, the image database “hymenoptera_data” I used only has a few hundred images and my own model is overfitting the data, hence the low accuracy.
#
# Sites that I referenced:
# - https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html#
# - https://youtu.be/DkNIBBBvcPs?feature=shared
# - https://youtu.be/ACmuBbuXn20?feature=shared

# %% [markdown]
# ### My own Detectron2 (library) implementation (in Linux Ubuntu)
# Only cpu and no CUDA since I’m using Ubuntu VM \
# Download and install Detectron2 guide: https://medium.com/@muhammadtalha1726/detectron-2-installation-guide-d12f66e220bf \
# Main tutorial followed to use Detectron2 to train models: https://gilberttanner.com/blog/detectron-2-object-detection-with-pytorch/

# %% [markdown]
# Create environment commands:

# %%
$ virtualenv -p python3 detectron
source detectron/bin/activate
# Out:
#   Cell In[5], line 1
#     $ virtualenv -p python3 detectron
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# Download and build detectron2: \
# After downloading detectron2 model from github, use

# %%
$ python -m pip install -e detectron2

# %% [markdown]
# from the directory that has the detectron2 folder to build it. \
# Note: For cv2 usage to work properly, you must login in Ubuntu via xorg!

# %%
from IPython.display import Image
Image("jupyter_images/cv2linux.jpg", width=400, height=100)

# %% [markdown]
# ### 柯导师要求训练的模型：

# %%
Image("jupyter_images/training_list.png", width=400, height=100)

# %%
Image("jupyter_images/instructions1.png", width=400, height=100)

# %% [markdown]
# ### Useful Links & References:
# - https://insightsimaging.springeropen.com/articles/10.1007/s13244-018-0639-9
